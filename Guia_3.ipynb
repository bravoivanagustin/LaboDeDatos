# %%
pip install gapminder

# %%
import seaborn as sns
import seaborn.objects as so
import pandas as pd
import matplotlib.pyplot as plt
from gapminder import gapminder

# %%
display(gapminder)
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
pxc = gapminder.groupby("continent")["country"].unique()
pxc
# Out:
# continent
# Africa      [Algeria, Angola, Benin, Botswana, Burkina Fas...
# Americas    [Argentina, Bolivia, Brazil, Canada, Chile, Co...
# Asia        [Afghanistan, Bahrain, Bangladesh, Cambodia, C...
# Europe      [Albania, Austria, Belgium, Bosnia and Herzego...
# Oceania                              [Australia, New Zealand]
# Name: country, dtype: object

# %%
(
    so.Plot(x = pxc.index, y = pxc)
    .add(so.Bar())
)

# %%
(
    so.Plot(data = gapminder, x = "continent")
    .add(so.Bar(), so.Hist())
)

# %%
sns.boxplot(gapminder, x = "continent", y = "lifeExp", order = sorted(gapminder["continent"].unique()))
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>

# %%
arg = gapminder[gapminder["country"] == "Argentina"]

# %%
(
    so.Plot(data = arg, x = "year", y = "lifeExp")
    .add(so.Line())
)

# %%
ame = gapminder[gapminder["continent"] == "Americas"]
asia = gapminder[gapminder["continent"] == "Asia"]

# %%
(
    so.Plot(data = ame, x = "year", y = "lifeExp", color = "country")
    .add(so.Line())
)

# %%
(
    so.Plot(data = ame, x = "year", y = "lifeExp")
    .add(so.Lines(color = "gray"), group = "country")
    .add(so.Line(), so.PolyFit(1))
)

# %%
(
    so.Plot(data = asia, x = "year", y = "lifeExp", color = "country")
    .add(so.Line())
)

# %%
(
    so.Plot(gapminder , x = "year", y = "lifeExp")
    .add(so.Lines(color = "lightgray"), group = "country")
    .add(so.Line(), so.PolyFit(1))
    .facet("continent", wrap = 3)
)

# %%
penguins = sns.load_dataset("penguins")

# %%
(
so.Plot(data = penguins , x = "bill_length_mm" , y = "bill_depth_mm" ,
edgewidth = "body_mass_g" , marker = "species" ,
linestyle = "island" , color = "species")
.add(so.Dot(color = ".8" ) , edgecolor = "sex")
)

# %%
(
    so.Plot(data = penguins, x = "bill_length_mm", y = "bill_depth_mm", color = "species")
    .add(so.Dot())
)

# %%
(
    so.Plot(data = penguins, x = "bill_length_mm", y = "bill_depth_mm", color = "sex")
    .add(so.Dot())
)

# %%
(
    so.Plot(data = penguins, x = "bill_length_mm", y = "bill_depth_mm", color = "sex")
    .add(so.Dot())
    .facet("species")
)

# %%
penguins.groupby("island").size()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# dtype: int64

# %%
pinguinos_por_isla = penguins.groupby("island").size()
(
    so.Plot(x = pinguinos_por_isla.index , y = pinguinos_por_isla)
    .add(so.Bar())
)

# %%
penguins["island"]
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 3      Torgersen
# 4      Torgersen
#          ...
# 339       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 344, dtype: object

# %%
(
    so.Plot(data = penguins, x = "island")
    .add(so.Bars(), so.Hist())
)

# %%
(
    so.Plot(data = penguins, x = "island", color = "species")
    .add(so.Bars(), so.Hist(), so.Dodge())
)

# %%
(
    so.Plot(data = penguins, x = "island", color = "species")
    .add(so.Bars(), so.Hist())
    .facet("species")
)

# %%
(
    so.Plot(data = penguins, x = "flipper_length_mm")
    .add(so.Bars(), so.Hist(bins = 10))
)

# %%
f = penguins["flipper_length_mm"]
print(f.mean(), f.median(), f.max(), f.min())
# Out:
# 200.91520467836258 197.0 231.0 172.0

# %%
b = penguins["bill_depth_mm"]
print(b.mean(), b.median(), b.max(), b.min())
# Out:
# 17.151169590643278 17.3 21.5 13.1

# %%
sns.boxplot(penguins, x = "species", y = "bill_depth_mm")
# Out:
# <Axes: xlabel='species', ylabel='bill_depth_mm'>

# %%
(
    so.Plot(data = penguins, x = "bill_length_mm", y = "bill_depth_mm", color = "species", pointsize = "body_mass_g")
    .add(so.Dot())
)

# %%
a = penguins[penguins["species"] == "Adelie"]
print(a["body_mass_g"].mean())
# Out:
# 3700.662251655629

# %%
g = penguins[penguins["species"] == "Gentoo"]
print(g["body_mass_g"].mean())
# Out:
# 5076.016260162602

# %%
c = penguins[penguins["species"] == "Chinstrap"]
print(c["body_mass_g"].mean())
# Out:
# 3733.0882352941176

# %%
sns.boxplot(penguins, x = "species", y = "body_mass_g")
# Out:
# <Axes: xlabel='species', ylabel='body_mass_g'>
